# %% [markdown]
# # Market Basket Analysis in Python using Apriori Algorithm

# %%
pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\neha reddy\anaconda3\lib\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing dataset

# %%
df = pd.read_csv("Groceriesdata.csv")

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  01-05-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  02-01-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  10-08-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  12-03-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df.shape
# Out:
# (38765, 3)

# %%
df.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %% [markdown]
# ### Preprocessing on Data

# %%
df.isna().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
#setting index as Date
df.set_index('Date',inplace = True)
df
# Out:
#             Member_number        itemDescription
# Date
# 21-07-2015           1808         tropical fruit
# 01-05-2015           2552             whole milk
# 19-09-2015           2300              pip fruit
# 12-12-2015           1187       other vegetables
# 02-01-2015           3037             whole milk
# ...                   ...                    ...
# 10-08-2014           4471          sliced cheese
# 23-02-2014           2022                  candy
# 16-04-2014           1097               cake bar
# 12-03-2014           1510  fruit/vegetable juice
# 26-12-2014           1521               cat food
#
# [38765 rows x 2 columns]

# %%
#converting date into a particular format
df.index=pd.to_datetime(df.index)
df
# Out:
#             Member_number        itemDescription
# Date
# 2015-07-21           1808         tropical fruit
# 2015-01-05           2552             whole milk
# 2015-09-19           2300              pip fruit
# 2015-12-12           1187       other vegetables
# 2015-02-01           3037             whole milk
# ...                   ...                    ...
# 2014-10-08           4471          sliced cheese
# 2014-02-23           2022                  candy
# 2014-04-16           1097               cake bar
# 2014-12-03           1510  fruit/vegetable juice
# 2014-12-26           1521               cat food
#
# [38765 rows x 2 columns]

# %%
#gathering information about products
total_item = len(df)
total_days = len(np.unique(df.index.date))
total_months = len(np.unique(df.index.year))
print(total_item,total_days,total_months)
# Out:
# 38765 728 2

# %% [markdown]
# #### Total items sold = 38765

# %% [markdown]
# #### Total days = 728

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = df.itemDescription.value_counts().head(10).index, y = df.itemDescription.value_counts().head(10).values, palette = 'gnuplot')
plt.xlabel('itemDescription', size = 15)
plt.xticks(rotation=45)
plt.ylabel('Count of Items', size = 15)
plt.title('Top 10 Items purchased by customers', color = 'black', size = 20)
plt.show()

# %% [markdown]
# ##### Here we need a data in form of list for Apriori Algorithm.

# %%
#grouping dataset to form a list of products bought by same customer on same date
df=df.groupby(['Member_number','Date'])['itemDescription'].apply(lambda x: list(x))

# %%
#apriori takes list as an input, hence converting dtaset to a list
orders = df.values.tolist()
orders[:10]
# Out:
# [['whole milk', 'pastry', 'salty snack'],
#  ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#  ['soda', 'pickled vegetables'],
#  ['canned beer', 'misc. beverages'],
#  ['sausage', 'hygiene articles'],
#  ['sausage', 'whole milk', 'rolls/buns'],
#  ['whole milk', 'soda'],
#  ['frankfurter', 'soda', 'whipped/sour cream'],
#  ['beef', 'white bread'],
#  ['frankfurter', 'curd']]

# %% [markdown]
# ## Apriori Algorithm Implementation

# %%
#applying apriori
from apyori import apriori
rules = apriori(orders, min_support=0.00030,min_confidence = 0.05,min_lift = 2,min_length = 2)
results = list(rules)

# %% [markdown]
# #### Number of relations

# %%
print("There are {} Relation derived.".format(len(results)))
# Out:
# There are 104 Relation derived.

# %% [markdown]
# #### Association Rules Derived

# %%
for i in range(0, len(results)):
    print(results[i][0])
# Out:
# frozenset({'artif. sweetener', 'soda'})
# frozenset({'berries', 'condensed milk'})
# frozenset({'whole milk', 'brandy'})
# frozenset({'sweet spreads', 'butter'})
# frozenset({'liver loaf', 'canned beer'})
# frozenset({'frozen fish', 'chocolate'})
# frozenset({'sauces', 'citrus fruit'})
# frozenset({'curd', 'cling film/bags'})
# frozenset({'condensed milk', 'waffles'})
# frozenset({'mustard', 'frankfurter'})
# frozenset({'liver loaf', 'fruit/vegetable juice'})
# frozenset({'pickled vegetables', 'ham'})
# frozenset({'hamburger meat', 'pasta'})
# frozenset({'hamburger meat', 'soft cheese'})
# frozenset({'hamburger meat', 'spread cheese'})
# frozenset({'roll products ', 'meat'})
# frozenset({'meat spreads', 'sausage'})
# frozenset({'salt', 'misc. beverages'})
# frozenset({'misc. beverages', 'spread cheese'})
# frozenset({'mustard', 'white bread'})
# frozenset({'sweet spreads', 'pip fruit'})
# frozenset({'pork', 'popcorn'})
# frozenset({'rum', 'sausage'})
# frozenset({'spices', 'sausage'})
# frozenset({'soups', 'seasonal products'})
# frozenset({'spices', 'soda'})
# frozenset({'sugar', 'spread cheese'})
# frozenset({'sweet spreads', 'tropical fruit'})
# frozenset({'whole milk', 'beef', 'bottled beer'})
# frozenset({'beef', 'whole milk', 'whipped/sour cream'})
# frozenset({'whole milk', 'beverages', 'sausage'})
# frozenset({'bottled beer', 'bottled water', 'sausage'})
# frozenset({'bottled beer', 'sausage', 'butter'})
# frozenset({'whole milk', 'chicken', 'bottled beer'})
# frozenset({'whole milk', 'bottled beer', 'chocolate'})
# frozenset({'bottled beer', 'rolls/buns', 'domestic eggs'})
# frozenset({'bottled beer', 'rolls/buns', 'frankfurter'})
# frozenset({'whole milk', 'bottled beer', 'hard cheese'})
# frozenset({'bottled water', 'yogurt', 'newspapers'})
# frozenset({'canned beer', 'brown bread', 'frozen vegetables'})
# frozenset({'canned beer', 'brown bread', 'sausage'})
# frozenset({'pork', 'whole milk', 'brown bread'})
# frozenset({'frankfurter', 'soda', 'butter'})
# frozenset({'shopping bags', 'soda', 'butter'})
# frozenset({'butter milk', 'canned beer', 'yogurt'})
# frozenset({'rolls/buns', 'yogurt', 'candy'})
# frozenset({'chicken', 'whole milk', 'canned beer'})
# frozenset({'canned beer', 'frozen vegetables', 'sausage'})
# frozenset({'whole milk', 'hygiene articles', 'canned beer'})
# frozenset({'pork', 'rolls/buns', 'canned beer'})
# frozenset({'yogurt', 'soda', 'chewing gum'})
# frozenset({'whole milk', 'yogurt', 'chewing gum'})
# frozenset({'citrus fruit', 'curd', 'other vegetables'})
# frozenset({'citrus fruit', 'yogurt', 'frankfurter'})
# frozenset({'citrus fruit', 'frozen vegetables', 'other vegetables'})
# frozenset({'pip fruit', 'citrus fruit', 'other vegetables'})
# frozenset({'citrus fruit', 'pork', 'other vegetables'})
# frozenset({'citrus fruit', 'pork', 'yogurt'})
# frozenset({'rolls/buns', 'coffee', 'frankfurter'})
# frozenset({'coffee', 'soda', 'frankfurter'})
# frozenset({'coffee', 'pastry', 'sausage'})
# frozenset({'root vegetables', 'coffee', 'soda'})
# frozenset({'cream cheese ', 'root vegetables', 'other vegetables'})
# frozenset({'sausage', 'curd', 'fruit/vegetable juice'})
# frozenset({'margarine', 'curd', 'sausage'})
# frozenset({'rolls/buns', 'curd', 'sausage'})
# frozenset({'yogurt', 'curd', 'sausage'})
# frozenset({'rolls/buns', 'dessert', 'soda'})
# frozenset({'whole milk', 'dessert', 'sausage'})
# frozenset({'other vegetables', 'domestic eggs', 'frankfurter'})
# frozenset({'other vegetables', 'root vegetables', 'frankfurter'})
# frozenset({'other vegetables', 'sausage', 'frankfurter'})
# frozenset({'sausage', 'soda', 'frankfurter'})
# frozenset({'rolls/buns', 'root vegetables', 'frozen vegetables'})
# frozenset({'whole milk', 'yogurt', 'grapes'})
# frozenset({'hard cheese', 'sausage', 'other vegetables'})
# frozenset({'ice cream', 'rolls/buns', 'pip fruit'})
# frozenset({'margarine', 'pork', 'other vegetables'})
# frozenset({'margarine', 'whole milk', 'pip fruit'})
# frozenset({'margarine', 'root vegetables', 'shopping bags'})
# frozenset({'margarine', 'yogurt', 'sausage'})
# frozenset({'pastry', 'newspapers', 'other vegetables'})
# frozenset({'sausage', 'newspapers', 'pastry'})
# frozenset({'soda', 'newspapers', 'pastry'})
# frozenset({'soda', 'newspapers', 'sausage'})
# frozenset({'onions', 'yogurt', 'tropical fruit'})
# frozenset({'onions', 'whole milk', 'yogurt'})
# frozenset({'shopping bags', 'sausage', 'other vegetables'})
# frozenset({'sausage', 'waffles', 'other vegetables'})
# frozenset({'white bread', 'sausage', 'other vegetables'})
# frozenset({'white bread', 'soda', 'other vegetables'})
# frozenset({'soft cheese', 'yogurt', 'other vegetables'})
# frozenset({'whole milk', 'sugar', 'other vegetables'})
# frozenset({'soda', 'pastry', 'sausage'})
# frozenset({'yogurt', 'pastry', 'sausage'})
# frozenset({'pork', 'soda', 'sausage'})
# frozenset({'whole milk', 'pork', 'sausage'})
# frozenset({'yogurt', 'pork', 'sausage'})
# frozenset({'whole milk', 'rolls/buns', 'processed cheese'})
# frozenset({'rolls/buns', 'whipped/sour cream', 'yogurt'})
# frozenset({'shopping bags', 'yogurt', 'sausage'})
# frozenset({'whole milk', 'yogurt', 'sausage'})
# frozenset({'whole milk', 'soda', 'pastry', 'other vegetables'})
# frozenset({'whole milk', 'rolls/buns', 'yogurt', 'sausage'})

# %% [markdown]
# #### Rules Generated

# %%
for item in results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: artif. sweetener -> soda
# Support: 0.00046782062420637575
# Confidence: 0.2413793103448276
# Lift: 2.4857251346797353
# =====================================
# Rule: berries -> condensed milk
# Support: 0.0003341575887188398
# Confidence: 0.05102040816326531
# Lift: 2.34177413296607
# =====================================
# Rule: whole milk -> brandy
# Support: 0.0008688097306689834
# Confidence: 0.34210526315789475
# Lift: 2.1662805978127717
# =====================================
# Rule: sweet spreads -> butter
# Support: 0.0003341575887188398
# Confidence: 0.07352941176470588
# Lift: 2.087705101015738
# =====================================
# Rule: liver loaf -> canned beer
# Support: 0.00040098910646260775
# Confidence: 0.12
# Lift: 2.5577777777777775
# =====================================
# Rule: frozen fish -> chocolate
# Support: 0.00040098910646260775
# Confidence: 0.058823529411764705
# Lift: 2.493417763706049
# =====================================
# Rule: sauces -> citrus fruit
# Support: 0.0003341575887188398
# Confidence: 0.11363636363636365
# Lift: 2.1387935963407663
# =====================================
# Rule: curd -> cling film/bags
# Support: 0.0003341575887188398
# Confidence: 0.06756756756756757
# Lift: 2.005979193479194
# =====================================
# Rule: condensed milk -> waffles
# Support: 0.0003341575887188398
# Confidence: 0.05102040816326531
# Lift: 2.7560229868120536
# =====================================
# Rule: mustard -> frankfurter
# Support: 0.0005346521419501437
# Confidence: 0.08695652173913045
# Lift: 2.302885725278954
# =====================================
# Rule: liver loaf -> fruit/vegetable juice
# Support: 0.00040098910646260775
# Confidence: 0.12
# Lift: 3.5276227897838903
# =====================================
# Rule: pickled vegetables -> ham
# Support: 0.0005346521419501437
# Confidence: 0.05970149253731344
# Lift: 3.4895055970149254
# =====================================
# Rule: hamburger meat -> pasta
# Support: 0.00046782062420637575
# Confidence: 0.05785123966942149
# Lift: 2.6471807314175955
# =====================================
# Rule: hamburger meat -> soft cheese
# Support: 0.0006014836596939117
# Confidence: 0.060000000000000005
# Lift: 2.745504587155964
# =====================================
# Rule: hamburger meat -> spread cheese
# Support: 0.0003341575887188398
# Confidence: 0.05
# Lift: 2.2879204892966363
# =====================================
# Rule: roll products  -> meat
# Support: 0.0003341575887188398
# Confidence: 0.06097560975609757
# Lift: 3.620547812620984
# =====================================
# Rule: meat spreads -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.14285714285714288
# Lift: 2.3671887359595005
# =====================================
# Rule: salt -> misc. beverages
# Support: 0.0003341575887188398
# Confidence: 0.05617977528089888
# Lift: 3.5619405827461437
# =====================================
# Rule: misc. beverages -> spread cheese
# Support: 0.0003341575887188398
# Confidence: 0.05
# Lift: 3.170127118644068
# =====================================
# Rule: mustard -> white bread
# Support: 0.0003341575887188398
# Confidence: 0.05434782608695652
# Lift: 2.2651992249000847
# =====================================
# Rule: sweet spreads -> pip fruit
# Support: 0.0005346521419501437
# Confidence: 0.11764705882352942
# Lift: 2.398301009777208
# =====================================
# Rule: pork -> popcorn
# Support: 0.0003341575887188398
# Confidence: 0.10416666666666667
# Lift: 2.808370870870871
# =====================================
# Rule: rum -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.15625
# Lift: 2.589112679955703
# =====================================
# Rule: spices -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.125
# Lift: 2.0712901439645623
# =====================================
# Rule: soups -> seasonal products
# Support: 0.0003341575887188398
# Confidence: 0.10416666666666667
# Lift: 14.704205974842768
# =====================================
# Rule: spices -> soda
# Support: 0.0006014836596939117
# Confidence: 0.225
# Lift: 2.317050929112182
# =====================================
# Rule: sugar -> spread cheese
# Support: 0.00040098910646260775
# Confidence: 0.06
# Lift: 3.3878490566037733
# =====================================
# Rule: sweet spreads -> tropical fruit
# Support: 0.0007351466951814476
# Confidence: 0.16176470588235295
# Lift: 2.387066365007542
# =====================================
# Rule: whole milk -> beef
# Support: 0.00040098910646260775
# Confidence: 0.37499999999999994
# Lift: 2.3745768091409225
# =====================================
# Rule: beef -> whole milk
# Support: 0.00046782062420637575
# Confidence: 0.33333333333333337
# Lift: 2.110734941458598
# =====================================
# Rule: whole milk -> beverages
# Support: 0.0003341575887188398
# Confidence: 0.1724137931034483
# Lift: 2.8569519227097415
# =====================================
# Rule: bottled beer -> bottled water
# Support: 0.0003341575887188398
# Confidence: 0.13157894736842107
# Lift: 2.1803054146995398
# =====================================
# Rule: bottled beer -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.2
# Lift: 3.3140642303433
# =====================================
# Rule: whole milk -> chicken
# Support: 0.0003341575887188398
# Confidence: 0.3333333333333333
# Lift: 2.110734941458598
# =====================================
# Rule: whole milk -> bottled beer
# Support: 0.0003341575887188398
# Confidence: 0.3333333333333333
# Lift: 2.110734941458598
# =====================================
# Rule: bottled beer -> rolls/buns
# Support: 0.0003341575887188398
# Confidence: 0.08333333333333333
# Lift: 2.246696696696697
# =====================================
# Rule: bottled beer -> rolls/buns
# Support: 0.0003341575887188398
# Confidence: 0.08333333333333333
# Lift: 2.2069321533923305
# =====================================
# Rule: whole milk -> bottled beer
# Support: 0.0003341575887188398
# Confidence: 0.4545454545454546
# Lift: 2.8782749201708158
# =====================================
# Rule: bottled water -> yogurt
# Support: 0.00040098910646260775
# Confidence: 0.2222222222222222
# Lift: 2.5876351059230434
# =====================================
# Rule: canned beer -> brown bread
# Support: 0.0003341575887188398
# Confidence: 0.1388888888888889
# Lift: 4.959891275523733
# =====================================
# Rule: canned beer -> brown bread
# Support: 0.00040098910646260775
# Confidence: 0.16666666666666666
# Lift: 2.7617201919527496
# =====================================
# Rule: pork -> whole milk
# Support: 0.0003341575887188398
# Confidence: 0.0746268656716418
# Lift: 2.011967191071669
# =====================================
# Rule: frankfurter -> soda
# Support: 0.0003341575887188398
# Confidence: 0.2380952380952381
# Lift: 2.451905745092256
# =====================================
# Rule: shopping bags -> soda
# Support: 0.0003341575887188398
# Confidence: 0.25
# Lift: 2.574501032346869
# =====================================
# Rule: butter milk -> canned beer
# Support: 0.0003341575887188398
# Confidence: 0.4166666666666667
# Lift: 4.851815823605707
# =====================================
# Rule: rolls/buns -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.2272727272727273
# Lift: 2.646444994694022
# =====================================
# Rule: chicken -> whole milk
# Support: 0.00040098910646260775
# Confidence: 0.3529411764705882
# Lift: 2.234895820367927
# =====================================
# Rule: canned beer -> frozen vegetables
# Support: 0.0003341575887188398
# Confidence: 0.25
# Lift: 4.142580287929125
# =====================================
# Rule: whole milk -> hygiene articles
# Support: 0.00040098910646260775
# Confidence: 0.5454545454545454
# Lift: 3.4539299042049785
# =====================================
# Rule: pork -> rolls/buns
# Support: 0.0003341575887188398
# Confidence: 0.07936507936507937
# Lift: 2.13971113971114
# =====================================
# Rule: yogurt -> soda
# Support: 0.00040098910646260775
# Confidence: 0.39999999999999997
# Lift: 4.657743190661479
# =====================================
# Rule: whole milk -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.2
# Lift: 2.3288715953307393
# =====================================
# Rule: citrus fruit -> curd
# Support: 0.0003341575887188398
# Confidence: 0.29411764705882354
# Lift: 2.4088026015003705
# =====================================
# Rule: citrus fruit -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.19230769230769232
# Lift: 2.2392996108949417
# =====================================
# Rule: citrus fruit -> frozen vegetables
# Support: 0.0003341575887188398
# Confidence: 0.06944444444444445
# Lift: 2.4799456377618667
# =====================================
# Rule: pip fruit -> citrus fruit
# Support: 0.00040098910646260775
# Confidence: 0.2727272727272727
# Lift: 2.2336169577548888
# =====================================
# Rule: citrus fruit -> pork
# Support: 0.00046782062420637575
# Confidence: 0.09722222222222222
# Lift: 2.6211461461461463
# =====================================
# Rule: citrus fruit -> pork
# Support: 0.00040098910646260775
# Confidence: 0.3
# Lift: 3.4933073929961087
# =====================================
# Rule: rolls/buns -> coffee
# Support: 0.0003341575887188398
# Confidence: 0.2272727272727273
# Lift: 2.066027836076439
# =====================================
# Rule: coffee -> soda
# Support: 0.0003341575887188398
# Confidence: 0.2272727272727273
# Lift: 2.340455483951699
# =====================================
# Rule: coffee -> pastry
# Support: 0.0003341575887188398
# Confidence: 0.2380952380952381
# Lift: 3.9453145599325
# =====================================
# Rule: root vegetables -> coffee
# Support: 0.00040098910646260775
# Confidence: 0.19999999999999998
# Lift: 2.059600825877495
# =====================================
# Rule: cream cheese  -> root vegetables
# Support: 0.0003341575887188398
# Confidence: 0.15625
# Lift: 2.245887367915466
# =====================================
# Rule: sausage -> curd
# Support: 0.0003341575887188398
# Confidence: 0.5
# Lift: 8.28516057585825
# =====================================
# Rule: margarine -> curd
# Support: 0.0003341575887188398
# Confidence: 0.3125
# Lift: 5.178225359911406
# =====================================
# Rule: rolls/buns -> curd
# Support: 0.00040098910646260775
# Confidence: 0.14634146341463414
# Lift: 2.4249250465926586
# =====================================
# Rule: yogurt -> curd
# Support: 0.00046782062420637575
# Confidence: 0.2058823529411765
# Lift: 3.4115367077063388
# =====================================
# Rule: rolls/buns -> dessert
# Support: 0.0003341575887188398
# Confidence: 0.2272727272727273
# Lift: 2.066027836076439
# =====================================
# Rule: whole milk -> dessert
# Support: 0.00040098910646260775
# Confidence: 0.16666666666666666
# Lift: 2.7617201919527496
# =====================================
# Rule: other vegetables -> domestic eggs
# Support: 0.00040098910646260775
# Confidence: 0.2857142857142857
# Lift: 2.339979670028931
# =====================================
# Rule: other vegetables -> root vegetables
# Support: 0.00040098910646260775
# Confidence: 0.07594936708860758
# Lift: 2.011381203091744
# =====================================
# Rule: other vegetables -> sausage
# Support: 0.00040098910646260775
# Confidence: 0.2727272727272727
# Lift: 2.2336169577548888
# =====================================
# Rule: sausage -> soda
# Support: 0.0003341575887188398
# Confidence: 0.2272727272727273
# Lift: 2.340455483951699
# =====================================
# Rule: rolls/buns -> root vegetables
# Support: 0.0003341575887188398
# Confidence: 0.05813953488372093
# Lift: 2.0762335571959816
# =====================================
# Rule: whole milk -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.1724137931034483
# Lift: 2.007647927009258
# =====================================
# Rule: hard cheese -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.2
# Lift: 3.3140642303433
# =====================================
# Rule: ice cream -> rolls/buns
# Support: 0.0003341575887188398
# Confidence: 0.5
# Lift: 4.545261239368165
# =====================================
# Rule: margarine -> pork
# Support: 0.0003341575887188398
# Confidence: 0.10416666666666667
# Lift: 2.808370870870871
# =====================================
# Rule: margarine -> whole milk
# Support: 0.00040098910646260775
# Confidence: 0.09836065573770492
# Lift: 2.005136909813731
# =====================================
# Rule: margarine -> root vegetables
# Support: 0.0003341575887188398
# Confidence: 0.1724137931034483
# Lift: 3.623353351414181
# =====================================
# Rule: margarine -> yogurt
# Support: 0.00040098910646260775
# Confidence: 0.21428571428571427
# Lift: 2.495219566425792
# =====================================
# Rule: pastry -> newspapers
# Support: 0.0003341575887188398
# Confidence: 0.09090909090909091
# Lift: 2.3372383630115587
# =====================================
# Rule: sausage -> newspapers
# Support: 0.0003341575887188398
# Confidence: 0.16666666666666666
# Lift: 2.7617201919527496
# =====================================
# Rule: soda -> newspapers
# Support: 0.0003341575887188398
# Confidence: 0.14285714285714288
# Lift: 2.7617201919527505
# =====================================
# Rule: soda -> newspapers
# Support: 0.00040098910646260775
# Confidence: 0.2222222222222222
# Lift: 2.2884453620861054
# =====================================
# Rule: onions -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.2777777777777778
# Lift: 3.2345438824038046
# =====================================
# Rule: onions -> whole milk
# Support: 0.00046782062420637575
# Confidence: 0.368421052631579
# Lift: 2.3329175668752926
# =====================================
# Rule: shopping bags -> sausage
# Support: 0.0005346521419501437
# Confidence: 0.2758620689655173
# Lift: 2.259290715890003
# =====================================
# Rule: sausage -> waffles
# Support: 0.0003341575887188398
# Confidence: 0.05555555555555556
# Lift: 3.001002807862014
# =====================================
# Rule: white bread -> sausage
# Support: 0.0003341575887188398
# Confidence: 0.05555555555555556
# Lift: 2.3155369854534205
# =====================================
# Rule: white bread -> soda
# Support: 0.00040098910646260775
# Confidence: 0.2608695652173913
# Lift: 2.136503176982937
# =====================================
# Rule: soft cheese -> yogurt
# Support: 0.0003341575887188398
# Confidence: 0.2777777777777778
# Lift: 3.2345438824038046
# =====================================
# Rule: whole milk -> sugar
# Support: 0.00046782062420637575
# Confidence: 0.368421052631579
# Lift: 2.3329175668752926
# =====================================
# Rule: soda -> pastry
# Support: 0.0005346521419501437
# Confidence: 0.13114754098360656
# Lift: 2.1731568723562624
# =====================================
# Rule: yogurt -> pastry
# Support: 0.00046782062420637575
# Confidence: 0.12962962962962962
# Lift: 2.1480045937410277
# =====================================
# Rule: pork -> soda
# Support: 0.00040098910646260775
# Confidence: 0.2608695652173913
# Lift: 2.686435859840211
# =====================================
# Rule: whole milk -> pork
# Support: 0.0006014836596939117
# Confidence: 0.391304347826087
# Lift: 2.4778192791035716
# =====================================
# Rule: yogurt -> pork
# Support: 0.00040098910646260775
# Confidence: 0.2608695652173913
# Lift: 3.037658602605312
# =====================================
# Rule: whole milk -> rolls/buns
# Support: 0.00040098910646260775
# Confidence: 0.2727272727272727
# Lift: 2.4792334032917265
# =====================================
# Rule: rolls/buns -> whipped/sour cream
# Support: 0.0006014836596939117
# Confidence: 0.20454545454545456
# Lift: 2.3818004952246197
# =====================================
# Rule: shopping bags -> yogurt
# Support: 0.00040098910646260775
# Confidence: 0.20689655172413793
# Lift: 2.4091775124111097
# =====================================
# Rule: whole milk -> yogurt
# Support: 0.0014702933903628951
# Confidence: 0.1317365269461078
# Lift: 2.1829165589087607
# =====================================
# Rule: whole milk -> soda
# Support: 0.0003341575887188398
# Confidence: 0.09090909090909091
# Lift: 7.817659352142111
# =====================================
# Rule: whole milk -> rolls/buns
# Support: 0.0003341575887188398
# Confidence: 0.0625
# Lift: 5.599925149700599
# =====================================

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
ordered_results = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])
ordered_results
# Out:
#        Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0    artif. sweetener            soda  0.000468    0.241379  2.485725
# 1      condensed milk         berries  0.000334    0.051020  2.341774
# 2              brandy      whole milk  0.000869    0.342105  2.166281
# 3       sweet spreads          butter  0.000334    0.073529  2.087705
# 4          liver loaf     canned beer  0.000401    0.120000  2.557778
# ..                ...             ...       ...         ...       ...
# 99         rolls/buns          yogurt  0.000601    0.204545  2.381800
# 100     shopping bags          yogurt  0.000401    0.206897  2.409178
# 101        whole milk         sausage  0.001470    0.131737  2.182917
# 102            pastry      whole milk  0.000334    0.090909  7.817659
# 103        rolls/buns      whole milk  0.000334    0.062500  5.599925
#
# [104 rows x 5 columns]
